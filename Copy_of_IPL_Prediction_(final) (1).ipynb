# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ---
#
# Uploading the data from google drive
#
#
# ---

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
match = pd.read_csv("/content/drive/MyDrive/IPL_Matches_2008_2022.csv")
deliveries = pd.read_csv("/content/drive/MyDrive/IPL_Ball_by_Ball_2008_2022.csv")

# %%
match
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# 3               Rajasthan Royals               Gujarat Titans
# 4            Sunrisers Hyderabad                 Punjab Kings
# ..                           ...                          ...
# 945        Kolkata Knight Riders              Deccan Chargers
# 946               Mumbai Indians  Royal Challengers Bangalore
# 947             Delhi Daredevils             Rajasthan Royals
# 948              Kings XI Punjab          Chennai Super Kings
# 949  Royal Challengers Bangalore        Kolkata Knight Riders
#
#                                           Venue                   TossWinner  \
# 0              Narendra Modi Stadium, Ahmedabad             Rajasthan Royals
# 1              Narendra Modi Stadium, Ahmedabad             Rajasthan Royals
# 2                         Eden Gardens, Kolkata         Lucknow Super Giants
# 3                         Eden Gardens, Kolkata               Gujarat Titans
# 4                      Wankhede Stadium, Mumbai          Sunrisers Hyderabad
# ..                                          ...                          ...
# 945                                Eden Gardens              Deccan Chargers
# 946                            Wankhede Stadium               Mumbai Indians
# 947                            Feroz Shah Kotla             Rajasthan Royals
# 948  Punjab Cricket Association Stadium, Mohali          Chennai Super Kings
# 949                       M Chinnaswamy Stadium  Royal Challengers Bangalore
#
#     TossDecision SuperOver                  WinningTeam    WonBy  Margin  \
# 0            bat         N               Gujarat Titans  Wickets     7.0
# 1          field         N             Rajasthan Royals  Wickets     7.0
# 2          field         N  Royal Challengers Bangalore     Runs    14.0
# 3          field         N               Gujarat Titans  Wickets     7.0
# 4            bat         N                 Punjab Kings  Wickets     5.0
# ..           ...       ...                          ...      ...     ...
# 945          bat         N        Kolkata Knight Riders  Wickets     5.0
# 946          bat         N  Royal Challengers Bangalore  Wickets     5.0
# 947          bat         N             Delhi Daredevils  Wickets     9.0
# 948          bat         N          Chennai Super Kings     Runs    33.0
# 949        field         N        Kolkata Knight Riders     Runs   140.0
#
#     method Player_of_Match                                       Team1Players  \
# 0      NaN       HH Pandya  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1      NaN      JC Buttler  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 2      NaN      RM Patidar  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 3      NaN       DA Miller  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 4      NaN   Harpreet Brar  ['PK Garg', 'Abhishek Sharma', 'RA Tripathi', ...
# ..     ...             ...                                                ...
# 945    NaN       DJ Hussey  ['WP Saha', 'BB McCullum', 'RT Ponting', 'SC G...
# 946    NaN      MV Boucher  ['L Ronchi', 'ST Jayasuriya', 'DJ Thornely', '...
# 947    NaN     MF Maharoof  ['G Gambhir', 'V Sehwag', 'S Dhawan', 'MK Tiwa...
# 948    NaN      MEK Hussey  ['K Goel', 'JR Hopes', 'KC Sangakkara', 'Yuvra...
# 949    NaN     BB McCullum  ['R Dravid', 'W Jaffer', 'V Kohli', 'JH Kallis...
#
#                                           Team2Players        Umpire1  \
# 0    ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...    CB Gaffaney
# 1    ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...    CB Gaffaney
# 2    ['Q de Kock', 'KL Rahul', 'M Vohra', 'DJ Hooda...  J Madanagopal
# 3    ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...   BNJ Oxenford
# 4    ['JM Bairstow', 'S Dhawan', 'M Shahrukh Khan',...   AK Chaudhary
# ..                                                 ...            ...
# 945  ['AC Gilchrist', 'Y Venugopal Rao', 'VVS Laxma...      BF Bowden
# 946  ['S Chanderpaul', 'R Dravid', 'LRPL Taylor', '...       SJ Davis
# 947  ['T Kohli', 'YK Pathan', 'SR Watson', 'M Kaif'...      Aleem Dar
# 948  ['PA Patel', 'ML Hayden', 'MEK Hussey', 'MS Dh...      MR Benson
# 949  ['SC Ganguly', 'BB McCullum', 'RT Ponting', 'D...      Asad Rauf
#
#             Umpire2
# 0       Nitin Menon
# 1       Nitin Menon
# 2          MA Gough
# 3         VK Sharma
# 4     NA Patwardhan
# ..              ...
# 945     K Hariharan
# 946       DJ Harper
# 947  GA Pratapkumar
# 948      SL Shastri
# 949     RE Koertzen
#
# [950 rows x 20 columns]

# %%
match.columns
# Out:
# Index(['ID', 'City', 'Date', 'Season', 'MatchNumber', 'Team1', 'Team2',
#        'Venue', 'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam',
#        'WonBy', 'Margin', 'method', 'Player_of_Match', 'Team1Players',
#        'Team2Players', 'Umpire1', 'Umpire2'],
#       dtype='object')

# %%
deliveries.head()
# Out:
#         ID  innings  overs  ballnumber       batter          bowler  \
# 0  1312200        1      0           1  YBK Jaiswal  Mohammed Shami
# 1  1312200        1      0           2  YBK Jaiswal  Mohammed Shami
# 2  1312200        1      0           3   JC Buttler  Mohammed Shami
# 3  1312200        1      0           4  YBK Jaiswal  Mohammed Shami
# 4  1312200        1      0           5  YBK Jaiswal  Mohammed Shami
#
#    non-striker extra_type  batsman_run  extras_run  total_run  non_boundary  \
# 0   JC Buttler        NaN            0           0          0             0
# 1   JC Buttler    legbyes            0           1          1             0
# 2  YBK Jaiswal        NaN            1           0          1             0
# 3   JC Buttler        NaN            0           0          0             0
# 4   JC Buttler        NaN            0           0          0             0
#
#    isWicketDelivery player_out kind fielders_involved       BattingTeam
# 0                 0        NaN  NaN               NaN  Rajasthan Royals
# 1                 0        NaN  NaN               NaN  Rajasthan Royals
# 2                 0        NaN  NaN               NaN  Rajasthan Royals
# 3                 0        NaN  NaN               NaN  Rajasthan Royals
# 4                 0        NaN  NaN               NaN  Rajasthan Royals

# %%
match.shape
# Out:
# (950, 20)

# %%
deliveries.shape
# Out:
# (225954, 17)

# %%
total_score = deliveries.groupby(['ID','innings']).sum()['total_run'].reset_index()
# Out:
# <ipython-input-9-b4b902843d1e>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   total_score = deliveries.groupby(['ID','innings']).sum()['total_run'].reset_index()

# %%
total_score
# Out:
#            ID  innings  total_run
# 0      335982        1        222
# 1      335982        2         82
# 2      335983        1        240
# 3      335983        2        207
# 4      335984        1        129
# ...       ...      ...        ...
# 1923  1312198        2        193
# 1924  1312199        1        157
# 1925  1312199        2        161
# 1926  1312200        1        130
# 1927  1312200        2        133
#
# [1928 rows x 3 columns]

# %%
ts_inning1=total_score[total_score['innings'] == 1]
ts_inning2=total_score[total_score['innings'] == 2]

# %%
match_df = match.merge(ts_inning1[['ID','total_run']],left_on='ID',right_on='ID')

# %%
match_df
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# 3               Rajasthan Royals               Gujarat Titans
# 4            Sunrisers Hyderabad                 Punjab Kings
# ..                           ...                          ...
# 945        Kolkata Knight Riders              Deccan Chargers
# 946               Mumbai Indians  Royal Challengers Bangalore
# 947             Delhi Daredevils             Rajasthan Royals
# 948              Kings XI Punjab          Chennai Super Kings
# 949  Royal Challengers Bangalore        Kolkata Knight Riders
#
#                                           Venue                   TossWinner  \
# 0              Narendra Modi Stadium, Ahmedabad             Rajasthan Royals
# 1              Narendra Modi Stadium, Ahmedabad             Rajasthan Royals
# 2                         Eden Gardens, Kolkata         Lucknow Super Giants
# 3                         Eden Gardens, Kolkata               Gujarat Titans
# 4                      Wankhede Stadium, Mumbai          Sunrisers Hyderabad
# ..                                          ...                          ...
# 945                                Eden Gardens              Deccan Chargers
# 946                            Wankhede Stadium               Mumbai Indians
# 947                            Feroz Shah Kotla             Rajasthan Royals
# 948  Punjab Cricket Association Stadium, Mohali          Chennai Super Kings
# 949                       M Chinnaswamy Stadium  Royal Challengers Bangalore
#
#     TossDecision  ...                  WinningTeam    WonBy Margin  method  \
# 0            bat  ...               Gujarat Titans  Wickets    7.0     NaN
# 1          field  ...             Rajasthan Royals  Wickets    7.0     NaN
# 2          field  ...  Royal Challengers Bangalore     Runs   14.0     NaN
# 3          field  ...               Gujarat Titans  Wickets    7.0     NaN
# 4            bat  ...                 Punjab Kings  Wickets    5.0     NaN
# ..           ...  ...                          ...      ...    ...     ...
# 945          bat  ...        Kolkata Knight Riders  Wickets    5.0     NaN
# 946          bat  ...  Royal Challengers Bangalore  Wickets    5.0     NaN
# 947          bat  ...             Delhi Daredevils  Wickets    9.0     NaN
# 948          bat  ...          Chennai Super Kings     Runs   33.0     NaN
# 949        field  ...        Kolkata Knight Riders     Runs  140.0     NaN
#
#     Player_of_Match                                       Team1Players  \
# 0         HH Pandya  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1        JC Buttler  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 2        RM Patidar  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 3         DA Miller  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 4     Harpreet Brar  ['PK Garg', 'Abhishek Sharma', 'RA Tripathi', ...
# ..              ...                                                ...
# 945       DJ Hussey  ['WP Saha', 'BB McCullum', 'RT Ponting', 'SC G...
# 946      MV Boucher  ['L Ronchi', 'ST Jayasuriya', 'DJ Thornely', '...
# 947     MF Maharoof  ['G Gambhir', 'V Sehwag', 'S Dhawan', 'MK Tiwa...
# 948      MEK Hussey  ['K Goel', 'JR Hopes', 'KC Sangakkara', 'Yuvra...
# 949     BB McCullum  ['R Dravid', 'W Jaffer', 'V Kohli', 'JH Kallis...
#
#                                           Team2Players        Umpire1  \
# 0    ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...    CB Gaffaney
# 1    ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...    CB Gaffaney
# 2    ['Q de Kock', 'KL Rahul', 'M Vohra', 'DJ Hooda...  J Madanagopal
# 3    ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...   BNJ Oxenford
# 4    ['JM Bairstow', 'S Dhawan', 'M Shahrukh Khan',...   AK Chaudhary
# ..                                                 ...            ...
# 945  ['AC Gilchrist', 'Y Venugopal Rao', 'VVS Laxma...      BF Bowden
# 946  ['S Chanderpaul', 'R Dravid', 'LRPL Taylor', '...       SJ Davis
# 947  ['T Kohli', 'YK Pathan', 'SR Watson', 'M Kaif'...      Aleem Dar
# 948  ['PA Patel', 'ML Hayden', 'MEK Hussey', 'MS Dh...      MR Benson
# 949  ['SC Ganguly', 'BB McCullum', 'RT Ponting', 'D...      Asad Rauf
#
#             Umpire2 total_run
# 0       Nitin Menon       130
# 1       Nitin Menon       157
# 2          MA Gough       207
# 3         VK Sharma       188
# 4     NA Patwardhan       157
# ..              ...       ...
# 945     K Hariharan       110
# 946       DJ Harper       165
# 947  GA Pratapkumar       129
# 948      SL Shastri       240
# 949     RE Koertzen       222
#
# [950 rows x 21 columns]

# %% [markdown]
# ---
#
#
# *Replacing* **old team names** with **new team names** and *eliminating* **obsolete teams**
#
#
# ---

# %%
match_df['Team1'].unique()
# Out:
# array(['Rajasthan Royals', 'Royal Challengers Bangalore',
#        'Sunrisers Hyderabad', 'Delhi Capitals', 'Chennai Super Kings',
#        'Gujarat Titans', 'Lucknow Super Giants', 'Kolkata Knight Riders',
#        'Punjab Kings', 'Mumbai Indians', 'Kings XI Punjab',
#        'Delhi Daredevils', 'Rising Pune Supergiant', 'Gujarat Lions',
#        'Rising Pune Supergiants', 'Pune Warriors', 'Deccan Chargers',
#        'Kochi Tuskers Kerala'], dtype=object)

# %%
match_df['Team1'] = match_df['Team1'].str.replace('Delhi Daredevils','Delhi Capitals')
match_df['Team2'] = match_df['Team2'].str.replace('Delhi Daredevils','Delhi Capitals')

match_df['Team1'] = match_df['Team1'].str.replace('Deccan Chargers','Sunrisers Hyderabad')
match_df['Team2'] = match_df['Team2'].str.replace('Deccan Chargers','Sunrisers Hyderabad')

match_df['Team1'] = match_df['Team1'].str.replace('Kings XI Punjab','Punjab Kings')
match_df['Team2'] = match_df['Team2'].str.replace('Kings XI Punjab','Punjab Kings')

# %%
match_df['Team1'].unique()
# Out:
# array(['Rajasthan Royals', 'Royal Challengers Bangalore',
#        'Sunrisers Hyderabad', 'Delhi Capitals', 'Chennai Super Kings',
#        'Gujarat Titans', 'Lucknow Super Giants', 'Kolkata Knight Riders',
#        'Punjab Kings', 'Mumbai Indians', 'Rising Pune Supergiant',
#        'Gujarat Lions', 'Rising Pune Supergiants', 'Pune Warriors',
#        'Kochi Tuskers Kerala'], dtype=object)

# %%
Teams = ['Chennai Super Kings','Royal Challengers Bangalore','Mumbai Indians','Kolkata Knight Riders','Sunrisers Hyderabad','Rajasthan Royals','Delhi Capitals','Gujarat Titans','Punjab Kings','Lucknow Super Giants']

# %%
match_df = match_df[match_df['Team1'].isin(Teams)]
match_df = match_df[match_df['Team2'].isin(Teams)]
match_df['Team1'].unique()
# Out:
# array(['Rajasthan Royals', 'Royal Challengers Bangalore',
#        'Sunrisers Hyderabad', 'Delhi Capitals', 'Chennai Super Kings',
#        'Gujarat Titans', 'Lucknow Super Giants', 'Kolkata Knight Riders',
#        'Punjab Kings', 'Mumbai Indians'], dtype=object)

# %%
match_df.shape
# Out:
# (835, 21)

# %%
for col in match_df.columns:
    print(col)
# Out:
# ID
# City
# Date
# Season
# MatchNumber
# Team1
# Team2
# Venue
# TossWinner
# TossDecision
# SuperOver
# WinningTeam
# WonBy
# Margin
# method
# Player_of_Match
# Team1Players
# Team2Players
# Umpire1
# Umpire2
# total_run

# %%
match_df['method'].unique()
# Out:
# array([nan, 'D/L'], dtype=object)

# %%
#Removing the matches where the Duckworth Lewis Method was applied
match_df = match_df[match_df['method'] != 'D/L']
match_df['method'].unique()
# Out:
# array([nan], dtype=object)

# %%
match_df=match_df[['ID','Venue','WinningTeam','total_run','Team1','Team2','TossWinner']]

# %%
merged= match_df.merge(deliveries,on='ID')
merged=merged[merged['innings']==2]
merged
# Out:
#              ID                             Venue            WinningTeam  \
# 120     1312200  Narendra Modi Stadium, Ahmedabad         Gujarat Titans
# 121     1312200  Narendra Modi Stadium, Ahmedabad         Gujarat Titans
# 122     1312200  Narendra Modi Stadium, Ahmedabad         Gujarat Titans
# 123     1312200  Narendra Modi Stadium, Ahmedabad         Gujarat Titans
# 124     1312200  Narendra Modi Stadium, Ahmedabad         Gujarat Titans
# ...         ...                               ...                    ...
# 196449   335982             M Chinnaswamy Stadium  Kolkata Knight Riders
# 196450   335982             M Chinnaswamy Stadium  Kolkata Knight Riders
# 196451   335982             M Chinnaswamy Stadium  Kolkata Knight Riders
# 196452   335982             M Chinnaswamy Stadium  Kolkata Knight Riders
# 196453   335982             M Chinnaswamy Stadium  Kolkata Knight Riders
#
#         total_run_x                        Team1                  Team2  \
# 120             130             Rajasthan Royals         Gujarat Titans
# 121             130             Rajasthan Royals         Gujarat Titans
# 122             130             Rajasthan Royals         Gujarat Titans
# 123             130             Rajasthan Royals         Gujarat Titans
# 124             130             Rajasthan Royals         Gujarat Titans
# ...             ...                          ...                    ...
# 196449          222  Royal Challengers Bangalore  Kolkata Knight Riders
# 196450          222  Royal Challengers Bangalore  Kolkata Knight Riders
# 196451          222  Royal Challengers Bangalore  Kolkata Knight Riders
# 196452          222  Royal Challengers Bangalore  Kolkata Knight Riders
# 196453          222  Royal Challengers Bangalore  Kolkata Knight Riders
#
#                          TossWinner  innings  overs  ballnumber  ...  \
# 120                Rajasthan Royals        2      0           1  ...
# 121                Rajasthan Royals        2      0           2  ...
# 122                Rajasthan Royals        2      0           3  ...
# 123                Rajasthan Royals        2      0           4  ...
# 124                Rajasthan Royals        2      0           5  ...
# ...                             ...      ...    ...         ...  ...
# 196449  Royal Challengers Bangalore        2     14           5  ...
# 196450  Royal Challengers Bangalore        2     14           6  ...
# 196451  Royal Challengers Bangalore        2     14           7  ...
# 196452  Royal Challengers Bangalore        2     15           1  ...
# 196453  Royal Challengers Bangalore        2     15           2  ...
#
#        extra_type batsman_run extras_run total_run_y  non_boundary  \
# 120           NaN           0          0           0             0
# 121           NaN           0          0           0             0
# 122           NaN           1          0           1             0
# 123           NaN           0          0           0             0
# 124           NaN           0          0           0             0
# ...           ...         ...        ...         ...           ...
# 196449    legbyes           0          1           1             0
# 196450        NaN           1          0           1             0
# 196451        NaN           0          0           0             0
# 196452      wides           0          1           1             0
# 196453        NaN           0          0           0             0
#
#         isWicketDelivery  player_out    kind  fielders_involved  \
# 120                    0         NaN     NaN                NaN
# 121                    0         NaN     NaN                NaN
# 122                    0         NaN     NaN                NaN
# 123                    0         NaN     NaN                NaN
# 124                    0         NaN     NaN                NaN
# ...                  ...         ...     ...                ...
# 196449                 0         NaN     NaN                NaN
# 196450                 0         NaN     NaN                NaN
# 196451                 0         NaN     NaN                NaN
# 196452                 0         NaN     NaN                NaN
# 196453                 1    SB Joshi  caught        BB McCullum
#
#                         BattingTeam
# 120                  Gujarat Titans
# 121                  Gujarat Titans
# 122                  Gujarat Titans
# 123                  Gujarat Titans
# 124                  Gujarat Titans
# ...                             ...
# 196449  Royal Challengers Bangalore
# 196450  Royal Challengers Bangalore
# 196451  Royal Challengers Bangalore
# 196452  Royal Challengers Bangalore
# 196453  Royal Challengers Bangalore
#
# [95083 rows x 23 columns]

# %%
merged['BattingTeam'] = merged['BattingTeam'].str.replace('Delhi Daredevils','Delhi Capitals')
merged['WinningTeam'] = merged['WinningTeam'].str.replace('Delhi Daredevils','Delhi Capitals')

merged['BattingTeam'] = merged['BattingTeam'].str.replace('Deccan Chargers','Sunrisers Hyderabad')
merged['WinningTeam'] = merged['WinningTeam'].str.replace('Deccan Chargers','Sunrisers Hyderabad')

merged['BattingTeam'] = merged['BattingTeam'].str.replace('Kings XI Punjab','Punjab Kings')
merged['WinningTeam'] = merged['WinningTeam'].str.replace('Kings XI Punjab','Punjab Kings')

merged = merged[merged['BattingTeam'].isin(Teams)]
merged = merged[merged['WinningTeam'].isin(Teams)]

# %%
merged['runs_scored_till_now'] = merged.groupby('ID').cumsum()['total_run_y']
# Out:
# <ipython-input-26-1f2120ff7572>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.cumsum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   merged['runs_scored_till_now'] = merged.groupby('ID').cumsum()['total_run_y']

# %%
merged['runs_to_chase'] = merged['total_run_x']-merged['runs_scored_till_now']

# %%
merged.columns
# Out:
# Index(['ID', 'Venue', 'WinningTeam', 'total_run_x', 'Team1', 'Team2',
#        'TossWinner', 'innings', 'overs', 'ballnumber', 'batter', 'bowler',
#        'non-striker', 'extra_type', 'batsman_run', 'extras_run', 'total_run_y',
#        'non_boundary', 'isWicketDelivery', 'player_out', 'kind',
#        'fielders_involved', 'BattingTeam', 'runs_scored_till_now',
#        'runs_to_chase'],
#       dtype='object')

# %%
merged['balls_remaining']=120-((merged['overs'])*6 + merged['ballnumber'])

# %% [markdown]
# ---
#
# For win/loss column
#
# ---

# %% [markdown]
# ---
#
#
#  FOR WICKETS
#
#
#
#
# ---

# %%
merged['player_out']=merged['player_out'].fillna(0)
merged['player_out'] = merged['player_out'].apply(lambda x:x if x == 0 else 1)
merged['player_out'].unique()
# Out:
# array([0, 1])

# %%
w = merged.groupby('ID').cumsum()['player_out'].values
merged['wickets taken'] = w
merged['wickets left'] = 10-w
merged.head()
# Out:
# <ipython-input-31-5ab883faca19>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.cumsum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   w = merged.groupby('ID').cumsum()['player_out'].values
#           ID                             Venue     WinningTeam  total_run_x  \
# 120  1312200  Narendra Modi Stadium, Ahmedabad  Gujarat Titans          130
# 121  1312200  Narendra Modi Stadium, Ahmedabad  Gujarat Titans          130
# 122  1312200  Narendra Modi Stadium, Ahmedabad  Gujarat Titans          130
# 123  1312200  Narendra Modi Stadium, Ahmedabad  Gujarat Titans          130
# 124  1312200  Narendra Modi Stadium, Ahmedabad  Gujarat Titans          130
#
#                 Team1           Team2        TossWinner  innings  overs  \
# 120  Rajasthan Royals  Gujarat Titans  Rajasthan Royals        2      0
# 121  Rajasthan Royals  Gujarat Titans  Rajasthan Royals        2      0
# 122  Rajasthan Royals  Gujarat Titans  Rajasthan Royals        2      0
# 123  Rajasthan Royals  Gujarat Titans  Rajasthan Royals        2      0
# 124  Rajasthan Royals  Gujarat Titans  Rajasthan Royals        2      0
#
#      ballnumber  ... isWicketDelivery player_out kind fielders_involved  \
# 120           1  ...                0          0  NaN               NaN
# 121           2  ...                0          0  NaN               NaN
# 122           3  ...                0          0  NaN               NaN
# 123           4  ...                0          0  NaN               NaN
# 124           5  ...                0          0  NaN               NaN
#
#         BattingTeam  runs_scored_till_now  runs_to_chase  balls_remaining  \
# 120  Gujarat Titans                     0            130              119
# 121  Gujarat Titans                     0            130              118
# 122  Gujarat Titans                     1            129              117
# 123  Gujarat Titans                     1            129              116
# 124  Gujarat Titans                     1            129              115
#
#      wickets taken  wickets left
# 120              0            10
# 121              0            10
# 122              0            10
# 123              0            10
# 124              0            10
#
# [5 rows x 28 columns]

# %%
def won(x):
  return 1 if x['BattingTeam'] == x['WinningTeam'] else 0

# %%
def tosswon(x):
  return 1 if x['BattingTeam'] == x['TossWinner'] else 0

# %%
merged['Tosswin'] = merged.apply(tosswon, axis=1)

merged.head()
# Out:
#           ID                             Venue     WinningTeam  total_run_x  \
# 120  1312200  Narendra Modi Stadium, Ahmedabad  Gujarat Titans          130
# 121  1312200  Narendra Modi Stadium, Ahmedabad  Gujarat Titans          130
# 122  1312200  Narendra Modi Stadium, Ahmedabad  Gujarat Titans          130
# 123  1312200  Narendra Modi Stadium, Ahmedabad  Gujarat Titans          130
# 124  1312200  Narendra Modi Stadium, Ahmedabad  Gujarat Titans          130
#
#                 Team1           Team2        TossWinner  innings  overs  \
# 120  Rajasthan Royals  Gujarat Titans  Rajasthan Royals        2      0
# 121  Rajasthan Royals  Gujarat Titans  Rajasthan Royals        2      0
# 122  Rajasthan Royals  Gujarat Titans  Rajasthan Royals        2      0
# 123  Rajasthan Royals  Gujarat Titans  Rajasthan Royals        2      0
# 124  Rajasthan Royals  Gujarat Titans  Rajasthan Royals        2      0
#
#      ballnumber  ... player_out kind fielders_involved     BattingTeam  \
# 120           1  ...          0  NaN               NaN  Gujarat Titans
# 121           2  ...          0  NaN               NaN  Gujarat Titans
# 122           3  ...          0  NaN               NaN  Gujarat Titans
# 123           4  ...          0  NaN               NaN  Gujarat Titans
# 124           5  ...          0  NaN               NaN  Gujarat Titans
#
#      runs_scored_till_now  runs_to_chase  balls_remaining  wickets taken  \
# 120                     0            130              119              0
# 121                     0            130              118              0
# 122                     1            129              117              0
# 123                     1            129              116              0
# 124                     1            129              115              0
#
#      wickets left  Tosswin
# 120            10        0
# 121            10        0
# 122            10        0
# 123            10        0
# 124            10        0
#
# [5 rows x 29 columns]

# %%
homeground_dict = {
    'Chennai Super Kings': ['JSCA International Stadium Complex', 'MA Chidambaram Stadium, Chepauk', 'MA Chidambaram Stadium', 'MA Chidambaram Stadium, Chepauk, Chennai', 'Maharashtra Cricket Association Stadium',
 'Maharashtra Cricket Association Stadium, Pune'],
    'Mumbai Indians': ['Wankhede Stadium','Wankhede Stadium, Mumbai' ,'Dr DY Patil Sports Academy, Mumbai','Dr DY Patil Sports Academy' ,'Brabourne Stadium','Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium','Brabourne Stadium, Mumbai' ],
    'Royal Challengers Bangalore': ['M Chinnaswamy Stadium', 'M.Chinnaswamy Stadium'],
    'Delhi Capitals': ['Arun Jaitley Stadium', 'Arun Jaitley Stadium, Delhi', 'Shaheed Veer Narayan Singh International Stadium'],
    'Punjab Kings': ['Barabati Stadium','Maharashtra Cricket Association Stadium', 'Maharashtra Cricket Association Stadium, Pune', 'Holkar Cricket Stadium'],
    'Rajasthan Royals': ['Sawai Mansingh Stadium', 'Narendra Modi Stadium, Ahmedabad','Brabourne Stadium', 'Brabourne Stadium, Mumbai'],
    'Kolkata Knight Riders': ['Eden Gardens, Kolkata','JSCA International Stadium Complex','Barabati Stadium'],
    'Sunrisers Hyderabad': [ 'Rajiv Gandhi International Stadium', 'Rajiv Gandhi International Stadium, Uppal','Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium'],
    'Gujarat Titans': ['Narendra Modi Stadium, Ahmedabad'],
    'Lucknow Super Giants': []
}

# %%
merged['homeground_advantage'] = merged.apply(lambda x: 1 if x['Venue'] in homeground_dict.get(x['BattingTeam'], []) else 0, axis=1)

# %%
#crr= runs scored / overs
merged['crr']= (merged['runs_scored_till_now']*6)/(120-(merged['balls_remaining']))
#rrr= runs left/ over left
merged['rrr']= (merged['runs_to_chase']*6)/(merged['balls_remaining'])

# %%
merged = merged[merged['rrr'] > 0]

# %%
merged['result'] = merged.apply(won, axis=1)
merged.head()
# Out:
#           ID                             Venue     WinningTeam  total_run_x  \
# 120  1312200  Narendra Modi Stadium, Ahmedabad  Gujarat Titans          130
# 121  1312200  Narendra Modi Stadium, Ahmedabad  Gujarat Titans          130
# 122  1312200  Narendra Modi Stadium, Ahmedabad  Gujarat Titans          130
# 123  1312200  Narendra Modi Stadium, Ahmedabad  Gujarat Titans          130
# 124  1312200  Narendra Modi Stadium, Ahmedabad  Gujarat Titans          130
#
#                 Team1           Team2        TossWinner  innings  overs  \
# 120  Rajasthan Royals  Gujarat Titans  Rajasthan Royals        2      0
# 121  Rajasthan Royals  Gujarat Titans  Rajasthan Royals        2      0
# 122  Rajasthan Royals  Gujarat Titans  Rajasthan Royals        2      0
# 123  Rajasthan Royals  Gujarat Titans  Rajasthan Royals        2      0
# 124  Rajasthan Royals  Gujarat Titans  Rajasthan Royals        2      0
#
#      ballnumber  ... runs_scored_till_now runs_to_chase balls_remaining  \
# 120           1  ...                    0           130             119
# 121           2  ...                    0           130             118
# 122           3  ...                    1           129             117
# 123           4  ...                    1           129             116
# 124           5  ...                    1           129             115
#
#     wickets taken  wickets left  Tosswin  homeground_advantage  crr       rrr  \
# 120             0            10        0                     1  0.0  6.554622
# 121             0            10        0                     1  0.0  6.610169
# 122             0            10        0                     1  2.0  6.615385
# 123             0            10        0                     1  1.5  6.672414
# 124             0            10        0                     1  1.2  6.730435
#
#      result
# 120       1
# 121       1
# 122       1
# 123       1
# 124       1
#
# [5 rows x 33 columns]

# %%
merged
# Out:
#              ID                             Venue            WinningTeam  \
# 120     1312200  Narendra Modi Stadium, Ahmedabad         Gujarat Titans
# 121     1312200  Narendra Modi Stadium, Ahmedabad         Gujarat Titans
# 122     1312200  Narendra Modi Stadium, Ahmedabad         Gujarat Titans
# 123     1312200  Narendra Modi Stadium, Ahmedabad         Gujarat Titans
# 124     1312200  Narendra Modi Stadium, Ahmedabad         Gujarat Titans
# ...         ...                               ...                    ...
# 196449   335982             M Chinnaswamy Stadium  Kolkata Knight Riders
# 196450   335982             M Chinnaswamy Stadium  Kolkata Knight Riders
# 196451   335982             M Chinnaswamy Stadium  Kolkata Knight Riders
# 196452   335982             M Chinnaswamy Stadium  Kolkata Knight Riders
# 196453   335982             M Chinnaswamy Stadium  Kolkata Knight Riders
#
#         total_run_x                        Team1                  Team2  \
# 120             130             Rajasthan Royals         Gujarat Titans
# 121             130             Rajasthan Royals         Gujarat Titans
# 122             130             Rajasthan Royals         Gujarat Titans
# 123             130             Rajasthan Royals         Gujarat Titans
# 124             130             Rajasthan Royals         Gujarat Titans
# ...             ...                          ...                    ...
# 196449          222  Royal Challengers Bangalore  Kolkata Knight Riders
# 196450          222  Royal Challengers Bangalore  Kolkata Knight Riders
# 196451          222  Royal Challengers Bangalore  Kolkata Knight Riders
# 196452          222  Royal Challengers Bangalore  Kolkata Knight Riders
# 196453          222  Royal Challengers Bangalore  Kolkata Knight Riders
#
#                          TossWinner  innings  overs  ballnumber  ...  \
# 120                Rajasthan Royals        2      0           1  ...
# 121                Rajasthan Royals        2      0           2  ...
# 122                Rajasthan Royals        2      0           3  ...
# 123                Rajasthan Royals        2      0           4  ...
# 124                Rajasthan Royals        2      0           5  ...
# ...                             ...      ...    ...         ...  ...
# 196449  Royal Challengers Bangalore        2     14           5  ...
# 196450  Royal Challengers Bangalore        2     14           6  ...
# 196451  Royal Challengers Bangalore        2     14           7  ...
# 196452  Royal Challengers Bangalore        2     15           1  ...
# 196453  Royal Challengers Bangalore        2     15           2  ...
#
#        runs_scored_till_now runs_to_chase balls_remaining wickets taken  \
# 120                       0           130             119             0
# 121                       0           130             118             0
# 122                       1           129             117             0
# 123                       1           129             116             0
# 124                       1           129             115             0
# ...                     ...           ...             ...           ...
# 196449                   80           142              31             9
# 196450                   81           141              30             9
# 196451                   81           141              29             9
# 196452                   82           140              29             9
# 196453                   82           140              28            10
#
#         wickets left  Tosswin  homeground_advantage       crr        rrr  \
# 120               10        0                     1  0.000000   6.554622
# 121               10        0                     1  0.000000   6.610169
# 122               10        0                     1  2.000000   6.615385
# 123               10        0                     1  1.500000   6.672414
# 124               10        0                     1  1.200000   6.730435
# ...              ...      ...                   ...       ...        ...
# 196449             1        1                     1  5.393258  27.483871
# 196450             1        1                     1  5.400000  28.200000
# 196451             1        1                     1  5.340659  29.172414
# 196452             1        1                     1  5.406593  28.965517
# 196453             0        1                     1  5.347826  30.000000
#
#         result
# 120          1
# 121          1
# 122          1
# 123          1
# 124          1
# ...        ...
# 196449       0
# 196450       0
# 196451       0
# 196452       0
# 196453       0
#
# [94295 rows x 33 columns]

# %% [markdown]
# ---
# For current run rate and required run rate
#
# ---

# %%
for col in merged.columns:
    print(col)
# Out:
# ID
# Venue
# WinningTeam
# total_run_x
# Team1
# Team2
# TossWinner
# innings
# overs
# ballnumber
# batter
# bowler
# non-striker
# extra_type
# batsman_run
# extras_run
# total_run_y
# non_boundary
# isWicketDelivery
# player_out
# kind
# fielders_involved
# BattingTeam
# runs_scored_till_now
# runs_to_chase
# balls_remaining
# wickets taken
# wickets left
# Tosswin
# homeground_advantage
# crr
# rrr
# result

# %%
cricket_table = merged[['ID','Team2','Team1','Venue','runs_scored_till_now',
'runs_to_chase','balls_remaining','wickets left','total_run_x','crr','rrr','result','Tosswin',"homeground_advantage"]]

cricket_table.rename(columns={'Team1':'BowlingTeam'},inplace=True)
cricket_table.rename(columns={'Team2':'BattingTeam'},inplace=True)
cricket_table.dropna(inplace=True)
cricket_table = cricket_table.sample(cricket_table.shape[0])
# Out:
# <ipython-input-42-42c11946951d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cricket_table.rename(columns={'Team1':'BowlingTeam'},inplace=True)
# <ipython-input-42-42c11946951d>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cricket_table.rename(columns={'Team2':'BattingTeam'},inplace=True)
# <ipython-input-42-42c11946951d>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cricket_table.dropna(inplace=True)

# %%
merged
# Out:
#              ID                             Venue            WinningTeam  \
# 120     1312200  Narendra Modi Stadium, Ahmedabad         Gujarat Titans
# 121     1312200  Narendra Modi Stadium, Ahmedabad         Gujarat Titans
# 122     1312200  Narendra Modi Stadium, Ahmedabad         Gujarat Titans
# 123     1312200  Narendra Modi Stadium, Ahmedabad         Gujarat Titans
# 124     1312200  Narendra Modi Stadium, Ahmedabad         Gujarat Titans
# ...         ...                               ...                    ...
# 196449   335982             M Chinnaswamy Stadium  Kolkata Knight Riders
# 196450   335982             M Chinnaswamy Stadium  Kolkata Knight Riders
# 196451   335982             M Chinnaswamy Stadium  Kolkata Knight Riders
# 196452   335982             M Chinnaswamy Stadium  Kolkata Knight Riders
# 196453   335982             M Chinnaswamy Stadium  Kolkata Knight Riders
#
#         total_run_x                        Team1                  Team2  \
# 120             130             Rajasthan Royals         Gujarat Titans
# 121             130             Rajasthan Royals         Gujarat Titans
# 122             130             Rajasthan Royals         Gujarat Titans
# 123             130             Rajasthan Royals         Gujarat Titans
# 124             130             Rajasthan Royals         Gujarat Titans
# ...             ...                          ...                    ...
# 196449          222  Royal Challengers Bangalore  Kolkata Knight Riders
# 196450          222  Royal Challengers Bangalore  Kolkata Knight Riders
# 196451          222  Royal Challengers Bangalore  Kolkata Knight Riders
# 196452          222  Royal Challengers Bangalore  Kolkata Knight Riders
# 196453          222  Royal Challengers Bangalore  Kolkata Knight Riders
#
#                          TossWinner  innings  overs  ballnumber  ...  \
# 120                Rajasthan Royals        2      0           1  ...
# 121                Rajasthan Royals        2      0           2  ...
# 122                Rajasthan Royals        2      0           3  ...
# 123                Rajasthan Royals        2      0           4  ...
# 124                Rajasthan Royals        2      0           5  ...
# ...                             ...      ...    ...         ...  ...
# 196449  Royal Challengers Bangalore        2     14           5  ...
# 196450  Royal Challengers Bangalore        2     14           6  ...
# 196451  Royal Challengers Bangalore        2     14           7  ...
# 196452  Royal Challengers Bangalore        2     15           1  ...
# 196453  Royal Challengers Bangalore        2     15           2  ...
#
#        runs_scored_till_now runs_to_chase balls_remaining wickets taken  \
# 120                       0           130             119             0
# 121                       0           130             118             0
# 122                       1           129             117             0
# 123                       1           129             116             0
# 124                       1           129             115             0
# ...                     ...           ...             ...           ...
# 196449                   80           142              31             9
# 196450                   81           141              30             9
# 196451                   81           141              29             9
# 196452                   82           140              29             9
# 196453                   82           140              28            10
#
#         wickets left  Tosswin  homeground_advantage       crr        rrr  \
# 120               10        0                     1  0.000000   6.554622
# 121               10        0                     1  0.000000   6.610169
# 122               10        0                     1  2.000000   6.615385
# 123               10        0                     1  1.500000   6.672414
# 124               10        0                     1  1.200000   6.730435
# ...              ...      ...                   ...       ...        ...
# 196449             1        1                     1  5.393258  27.483871
# 196450             1        1                     1  5.400000  28.200000
# 196451             1        1                     1  5.340659  29.172414
# 196452             1        1                     1  5.406593  28.965517
# 196453             0        1                     1  5.347826  30.000000
#
#         result
# 120          1
# 121          1
# 122          1
# 123          1
# 124          1
# ...        ...
# 196449       0
# 196450       0
# 196451       0
# 196452       0
# 196453       0
#
# [94295 rows x 33 columns]

# %%
cricket_table
# Out:
#              ID                  BattingTeam                  BowlingTeam  \
# 66388   1136599  Royal Challengers Bangalore          Sunrisers Hyderabad
# 40201   1216540        Kolkata Knight Riders  Royal Challengers Bangalore
# 137212   548354             Rajasthan Royals                 Punjab Kings
# 28844   1254072        Kolkata Knight Riders          Chennai Super Kings
# 113276   729309               Mumbai Indians               Delhi Capitals
# ...         ...                          ...                          ...
# 165497   419128               Delhi Capitals  Royal Challengers Bangalore
# 155880   419165               Mumbai Indians          Chennai Super Kings
# 79549   1082608        Kolkata Knight Riders               Delhi Capitals
# 32755   1237180          Sunrisers Hyderabad               Delhi Capitals
# 22881   1254100          Sunrisers Hyderabad             Rajasthan Royals
#
#                                              Venue  runs_scored_till_now  \
# 66388           Rajiv Gandhi International Stadium                    53
# 40201                      Sharjah Cricket Stadium                    87
# 137212  Punjab Cricket Association Stadium, Mohali                    84
# 28844                     Wankhede Stadium, Mumbai                    66
# 113276                     Sharjah Cricket Stadium                    12
# ...                                            ...                   ...
# 165497                       M Chinnaswamy Stadium                    75
# 155880                  Dr DY Patil Sports Academy                    82
# 79549                             Feroz Shah Kotla                   127
# 32755                         Sheikh Zayed Stadium                    66
# 22881          Dubai International Cricket Stadium                   114
#
#         runs_to_chase  balls_remaining  wickets left  total_run_x       crr  \
# 66388              93               86             9          146  9.352941
# 40201             107               34             4          194  6.069767
# 137212             93               41             6          177  6.379747
# 28844             154               72             5          220  8.250000
# 113276            113              109            10          125  6.545455
# ...               ...              ...           ...          ...       ...
# 165497            108               64             9          183  8.035714
# 155880             86               39             7          168  6.074074
# 79549              41               34             7          168  8.860465
# 32755             123               64             7          189  7.071429
# 22881              50               47             8          164  9.369863
#
#               rrr  result  Tosswin  homeground_advantage
# 66388    6.488372       0        1                     0
# 40201   18.882353       0        0                     0
# 137212  13.609756       0        0                     0
# 28844   12.833333       0        1                     0
# 113276   6.220183       1        0                     0
# ...           ...     ...      ...                   ...
# 165497  10.125000       0        1                     1
# 155880  13.230769       0        0                     1
# 79549    7.235294       1        0                     0
# 32755   11.531250       0        0                     0
# 22881    6.382979       1        0                     0
#
# [94295 rows x 14 columns]

# %%
summary_table= cricket_table[cricket_table['balls_remaining']==0]
summary_table=summary_table[['ID','BattingTeam','BowlingTeam','runs_scored_till_now','total_run_x','crr','result',"wickets left",'Venue']]

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(summary_table['total_run_x'], summary_table['wickets left'])
plt.xlabel('Total Runs Scored')
plt.ylabel('Wickets Left')
plt.title('Total Runs Scored vs. Wickets Left for Batting Team')
plt.show()

# %%
team_summary = summary_table.groupby('BattingTeam').agg({'ID': 'count', 'total_run_x': 'mean'})

# Rename the columns
team_summary = team_summary.rename(columns={'ID': 'MatchesPlayed', 'total_run_x': 'RunsPerMatch'})

# Display the summary table
print(team_summary)
# Out:
#                              MatchesPlayed  RunsPerMatch
# BattingTeam
# Chennai Super Kings                     23    183.652174
# Delhi Capitals                          36    178.250000
# Gujarat Titans                           2    183.000000
# Kolkata Knight Riders                   37    177.162162
# Lucknow Super Giants                     4    182.750000
# Mumbai Indians                          39    175.897436
# Punjab Kings                            37    179.918919
# Rajasthan Royals                        32    177.156250
# Royal Challengers Bangalore             32    186.312500
# Sunrisers Hyderabad                     45    178.844444

# %%
import seaborn as sns

# %%
cricket_table['crr'].value_counts()
# Out:
# 6.000000     2693
# 0.000000     1075
# 8.000000     1039
# 9.000000     1000
# 7.500000      791
#              ...
# 4.219780        1
# 5.019231        1
# 17.333333       1
# 10.476190       1
# 14.062500       1
# Name: crr, Length: 5628, dtype: int64

# %%
cricket_table['rrr'].value_counts()
# Out:
# 6.000000      943
# 12.000000     807
# 9.000000      771
# 8.000000      459
# 10.000000     363
#              ...
# 5.724771        1
# 21.260870       1
# 127.500000      1
# 3.060000        1
# 12.627907       1
# Name: rrr, Length: 9235, dtype: int64

# %%
min_value = cricket_table['crr'].min()
max_value = cricket_table['crr'].max()

# Print the range of values
print("Range of values: {} - {}".format(min_value, max_value))
# Out:
# Range of values: 0.0 - 36.0

# %%
cricket_table = cricket_table.replace([np.inf, -np.inf], np.nan)  # Replace inf values with NaN
cricket_table = cricket_table.dropna(subset=['rrr'])

# %%
min_value = cricket_table['rrr'].min()
max_value = cricket_table['rrr'].max()

# Print the range of values
print("Range of values: {} - {}".format(min_value, max_value))
# Out:
# Range of values: 0.08333333333333333 - 708.0

# %%
cricket_table['BattingTeam'].unique()
# Out:
# array(['Royal Challengers Bangalore', 'Kolkata Knight Riders',
#        'Rajasthan Royals', 'Mumbai Indians', 'Sunrisers Hyderabad',
#        'Delhi Capitals', 'Punjab Kings', 'Chennai Super Kings',
#        'Gujarat Titans', 'Lucknow Super Giants'], dtype=object)

# %%
sorted(cricket_table['Venue'].unique())
# Out:
# ['Arun Jaitley Stadium',
#  'Arun Jaitley Stadium, Delhi',
#  'Barabati Stadium',
#  'Brabourne Stadium',
#  'Brabourne Stadium, Mumbai',
#  'Buffalo Park',
#  'De Beers Diamond Oval',
#  'Dr DY Patil Sports Academy',
#  'Dr DY Patil Sports Academy, Mumbai',
#  'Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium',
#  'Dubai International Cricket Stadium',
#  'Eden Gardens',
#  'Eden Gardens, Kolkata',
#  'Feroz Shah Kotla',
#  'Himachal Pradesh Cricket Association Stadium',
#  'Holkar Cricket Stadium',
#  'JSCA International Stadium Complex',
#  'Kingsmead',
#  'M Chinnaswamy Stadium',
#  'M.Chinnaswamy Stadium',
#  'MA Chidambaram Stadium',
#  'MA Chidambaram Stadium, Chepauk',
#  'MA Chidambaram Stadium, Chepauk, Chennai',
#  'Maharashtra Cricket Association Stadium',
#  'Maharashtra Cricket Association Stadium, Pune',
#  'Narendra Modi Stadium, Ahmedabad',
#  'New Wanderers Stadium',
#  'Newlands',
#  'OUTsurance Oval',
#  'Punjab Cricket Association IS Bindra Stadium',
#  'Punjab Cricket Association IS Bindra Stadium, Mohali',
#  'Punjab Cricket Association Stadium, Mohali',
#  'Rajiv Gandhi International Stadium',
#  'Rajiv Gandhi International Stadium, Uppal',
#  'Sardar Patel Stadium, Motera',
#  'Sawai Mansingh Stadium',
#  'Shaheed Veer Narayan Singh International Stadium',
#  'Sharjah Cricket Stadium',
#  'Sheikh Zayed Stadium',
#  "St George's Park",
#  'Subrata Roy Sahara Stadium',
#  'SuperSport Park',
#  'Vidarbha Cricket Association Stadium, Jamtha',
#  'Wankhede Stadium',
#  'Wankhede Stadium, Mumbai',
#  'Zayed Cricket Stadium, Abu Dhabi']

# %%
cricket_table.columns
# Out:
# Index(['ID', 'BattingTeam', 'BowlingTeam', 'Venue', 'runs_scored_till_now',
#        'runs_to_chase', 'balls_remaining', 'wickets left', 'total_run_x',
#        'crr', 'rrr', 'result', 'Tosswin', 'homeground_advantage'],
#       dtype='object')

# %%
cricket_table = cricket_table[['ID', 'BattingTeam', 'BowlingTeam', 'Venue', 'runs_scored_till_now',
       'runs_to_chase', 'balls_remaining', 'wickets left', 'total_run_x',
       'crr', 'rrr', 'Tosswin', 'homeground_advantage', 'result']]

# %%
cricket_table=cricket_table.sample(cricket_table.shape[0])

# %%
cricket_table.sample()
# Out:
#             ID   BattingTeam          BowlingTeam             Venue  \
# 167698  419117  Punjab Kings  Sunrisers Hyderabad  Barabati Stadium
#
#         runs_scored_till_now  runs_to_chase  balls_remaining  wickets left  \
# 167698                    42            128               76             7
#
#         total_run_x       crr        rrr  Tosswin  homeground_advantage  \
# 167698          170  5.727273  10.105263        0                     1
#
#         result
# 167698       0

# %%
X = cricket_table.iloc[:,:-1]
Y = cricket_table.iloc[:,-1]
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2,random_state=1)

# %%
X_train
# Out:
#              ID            BattingTeam            BowlingTeam  \
# 39900   1216528    Sunrisers Hyderabad    Chennai Super Kings
# 15233   1304058    Sunrisers Hyderabad   Lucknow Super Giants
# 77694   1082627  Kolkata Knight Riders    Sunrisers Hyderabad
# 58693   1175367       Rajasthan Royals    Chennai Super Kings
# 23826   1254107    Sunrisers Hyderabad           Punjab Kings
# ...         ...                    ...                    ...
# 63902   1136610           Punjab Kings         Mumbai Indians
# 15976   1304055         Mumbai Indians       Rajasthan Royals
# 176919   392211  Kolkata Knight Riders         Delhi Capitals
# 40910   1216523           Punjab Kings  Kolkata Knight Riders
# 131164   597998         Delhi Capitals  Kolkata Knight Riders
#
#                                             Venue  runs_scored_till_now  \
# 39900         Dubai International Cricket Stadium                    40
# 15233          Dr DY Patil Sports Academy, Mumbai                   156
# 77694   Rajiv Gandhi International Stadium, Uppal                     5
# 58693                      MA Chidambaram Stadium                    71
# 23826                     Sharjah Cricket Stadium                    22
# ...                                           ...                   ...
# 63902                            Wankhede Stadium                   167
# 15976          Dr DY Patil Sports Academy, Mumbai                   165
# 176919                                  Kingsmead                    63
# 40910                        Sheikh Zayed Stadium                    74
# 131164                               Eden Gardens                    69
#
#         runs_to_chase  balls_remaining  wickets left  total_run_x       crr  \
# 39900             127               84             8          167  6.666667
# 15233              13                3             3          169  8.000000
# 77694             204              116            10          209  7.500000
# 58693             104               68             7          175  8.192308
# 23826             103               82             8          125  3.473684
# ...               ...              ...           ...          ...       ...
# 63902              19                9             7          186  9.027027
# 15976              28                3             3          193  8.461538
# 176919             91               70             9          154  7.560000
# 40910              90               61            10          164  7.525424
# 131164             59               64             8          128  7.392857
#
#               rrr  Tosswin  homeground_advantage
# 39900    9.071429        0                     0
# 15233   26.000000        1                     0
# 77694   10.551724        1                     0
# 58693    9.176471        1                     0
# 23826    7.536585        1                     0
# ...           ...      ...                   ...
# 63902   12.666667        0                     0
# 15976   56.000000        1                     1
# 176919   7.800000        0                     0
# 40910    8.852459        0                     0
# 131164   5.531250        1                     0
#
# [75206 rows x 13 columns]

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
trf=ColumnTransformer([
    ("trf",OneHotEncoder(sparse=False,drop="first"),["BattingTeam","BowlingTeam","Venue"])
]
,remainder = "passthrough")

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline

# %%
pipe = Pipeline(steps=[
    ("step1",trf),
    ("step2",LogisticRegression(solver="liblinear"))
])

# %%
pipe.fit(X_train,Y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('trf',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse=False),
#                                                   ['BattingTeam', 'BowlingTeam',
#                                                    'Venue'])])),
#                 ('step2', LogisticRegression(solver='liblinear'))])

# %%
Y_pred=pipe.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(Y_test,Y_pred)
# Out:
# 0.7722582703967663

# %%
pipe.predict_proba(X_test)[4]
# Out:
# array([0.87856642, 0.12143358])

# %%
cricket_table.columns
# Out:
# Index(['ID', 'BattingTeam', 'BowlingTeam', 'Venue', 'runs_scored_till_now',
#        'runs_to_chase', 'balls_remaining', 'wickets left', 'total_run_x',
#        'crr', 'rrr', 'Tosswin', 'homeground_advantage', 'result'],
#       dtype='object')

# %%
merged
# Out:
#              ID                             Venue            WinningTeam  \
# 120     1312200  Narendra Modi Stadium, Ahmedabad         Gujarat Titans
# 121     1312200  Narendra Modi Stadium, Ahmedabad         Gujarat Titans
# 122     1312200  Narendra Modi Stadium, Ahmedabad         Gujarat Titans
# 123     1312200  Narendra Modi Stadium, Ahmedabad         Gujarat Titans
# 124     1312200  Narendra Modi Stadium, Ahmedabad         Gujarat Titans
# ...         ...                               ...                    ...
# 196449   335982             M Chinnaswamy Stadium  Kolkata Knight Riders
# 196450   335982             M Chinnaswamy Stadium  Kolkata Knight Riders
# 196451   335982             M Chinnaswamy Stadium  Kolkata Knight Riders
# 196452   335982             M Chinnaswamy Stadium  Kolkata Knight Riders
# 196453   335982             M Chinnaswamy Stadium  Kolkata Knight Riders
#
#         total_run_x                        Team1                  Team2  \
# 120             130             Rajasthan Royals         Gujarat Titans
# 121             130             Rajasthan Royals         Gujarat Titans
# 122             130             Rajasthan Royals         Gujarat Titans
# 123             130             Rajasthan Royals         Gujarat Titans
# 124             130             Rajasthan Royals         Gujarat Titans
# ...             ...                          ...                    ...
# 196449          222  Royal Challengers Bangalore  Kolkata Knight Riders
# 196450          222  Royal Challengers Bangalore  Kolkata Knight Riders
# 196451          222  Royal Challengers Bangalore  Kolkata Knight Riders
# 196452          222  Royal Challengers Bangalore  Kolkata Knight Riders
# 196453          222  Royal Challengers Bangalore  Kolkata Knight Riders
#
#                          TossWinner  innings  overs  ballnumber  ...  \
# 120                Rajasthan Royals        2      0           1  ...
# 121                Rajasthan Royals        2      0           2  ...
# 122                Rajasthan Royals        2      0           3  ...
# 123                Rajasthan Royals        2      0           4  ...
# 124                Rajasthan Royals        2      0           5  ...
# ...                             ...      ...    ...         ...  ...
# 196449  Royal Challengers Bangalore        2     14           5  ...
# 196450  Royal Challengers Bangalore        2     14           6  ...
# 196451  Royal Challengers Bangalore        2     14           7  ...
# 196452  Royal Challengers Bangalore        2     15           1  ...
# 196453  Royal Challengers Bangalore        2     15           2  ...
#
#        runs_scored_till_now runs_to_chase balls_remaining wickets taken  \
# 120                       0           130             119             0
# 121                       0           130             118             0
# 122                       1           129             117             0
# 123                       1           129             116             0
# 124                       1           129             115             0
# ...                     ...           ...             ...           ...
# 196449                   80           142              31             9
# 196450                   81           141              30             9
# 196451                   81           141              29             9
# 196452                   82           140              29             9
# 196453                   82           140              28            10
#
#         wickets left  Tosswin  homeground_advantage       crr        rrr  \
# 120               10        0                     1  0.000000   6.554622
# 121               10        0                     1  0.000000   6.610169
# 122               10        0                     1  2.000000   6.615385
# 123               10        0                     1  1.500000   6.672414
# 124               10        0                     1  1.200000   6.730435
# ...              ...      ...                   ...       ...        ...
# 196449             1        1                     1  5.393258  27.483871
# 196450             1        1                     1  5.400000  28.200000
# 196451             1        1                     1  5.340659  29.172414
# 196452             1        1                     1  5.406593  28.965517
# 196453             0        1                     1  5.347826  30.000000
#
#         result
# 120          1
# 121          1
# 122          1
# 123          1
# 124          1
# ...        ...
# 196449       0
# 196450       0
# 196451       0
# 196452       0
# 196453       0
#
# [94295 rows x 33 columns]

# %%
def filter_match_data(x_df):

    match = x_df[x_df['ballnumber'] == 6]
    return match

# %%
filter_match_data(merged).columns
# Out:
# Index(['ID', 'Venue', 'WinningTeam', 'total_run_x', 'Team1', 'Team2',
#        'TossWinner', 'innings', 'overs', 'ballnumber', 'batter', 'bowler',
#        'non-striker', 'extra_type', 'batsman_run', 'extras_run', 'total_run_y',
#        'non_boundary', 'isWicketDelivery', 'player_out', 'kind',
#        'fielders_involved', 'BattingTeam', 'runs_scored_till_now',
#        'runs_to_chase', 'balls_remaining', 'wickets taken', 'wickets left',
#        'Tosswin', 'homeground_advantage', 'crr', 'rrr', 'result'],
#       dtype='object')

# %%
match=filter_match_data(merged)

# %%
merged.rename(columns={'Team1': 'BowlingTeam'}, inplace=True)

# %%
match=filter_match_data(merged)

# %%
match.columns
# Out:
# Index(['ID', 'Venue', 'WinningTeam', 'total_run_x', 'BowlingTeam', 'Team2',
#        'TossWinner', 'innings', 'overs', 'ballnumber', 'batter', 'bowler',
#        'non-striker', 'extra_type', 'batsman_run', 'extras_run', 'total_run_y',
#        'non_boundary', 'isWicketDelivery', 'player_out', 'kind',
#        'fielders_involved', 'BattingTeam', 'runs_scored_till_now',
#        'runs_to_chase', 'balls_remaining', 'wickets taken', 'wickets left',
#        'Tosswin', 'homeground_advantage', 'crr', 'rrr', 'result'],
#       dtype='object')

# %%
def filter_temp_data(match_df):
    temp_df = match_df[['ID','BattingTeam', 'BowlingTeam', 'Venue', 'runs_to_chase', 'balls_remaining', 'wickets left', 'total_run_x', 'crr', 'rrr', 'Tosswin', 'homeground_advantage','runs_scored_till_now','result']].dropna()

    return temp_df

# %%
 filter_temp_data(match)
# Out:
#              ID                  BattingTeam                  BowlingTeam  \
# 125     1312200               Gujarat Titans             Rajasthan Royals
# 131     1312200               Gujarat Titans             Rajasthan Royals
# 137     1312200               Gujarat Titans             Rajasthan Royals
# 143     1312200               Gujarat Titans             Rajasthan Royals
# 150     1312200               Gujarat Titans             Rajasthan Royals
# ...         ...                          ...                          ...
# 196425   335982  Royal Challengers Bangalore  Royal Challengers Bangalore
# 196431   335982  Royal Challengers Bangalore  Royal Challengers Bangalore
# 196437   335982  Royal Challengers Bangalore  Royal Challengers Bangalore
# 196444   335982  Royal Challengers Bangalore  Royal Challengers Bangalore
# 196450   335982  Royal Challengers Bangalore  Royal Challengers Bangalore
#
#                                    Venue  runs_to_chase  balls_remaining  \
# 125     Narendra Modi Stadium, Ahmedabad            125              114
# 131     Narendra Modi Stadium, Ahmedabad            119              108
# 137     Narendra Modi Stadium, Ahmedabad            119              102
# 143     Narendra Modi Stadium, Ahmedabad            108               96
# 150     Narendra Modi Stadium, Ahmedabad            106               90
# ...                                  ...            ...              ...
# 196425             M Chinnaswamy Stadium            166               54
# 196431             M Chinnaswamy Stadium            163               48
# 196437             M Chinnaswamy Stadium            153               42
# 196444             M Chinnaswamy Stadium            145               36
# 196450             M Chinnaswamy Stadium            141               30
#
#         wickets left  total_run_x       crr        rrr  Tosswin  \
# 125               10          130  5.000000   6.578947        0
# 131                9          130  5.500000   6.611111        0
# 137                9          130  3.666667   7.000000        0
# 143                9          130  5.500000   6.750000        0
# 150                8          130  4.800000   7.066667        0
# ...              ...          ...       ...        ...      ...
# 196425             3          222  5.090909  18.444444        1
# 196431             2          222  4.916667  20.375000        1
# 196437             2          222  5.307692  21.857143        1
# 196444             1          222  5.500000  24.166667        1
# 196450             1          222  5.400000  28.200000        1
#
#         homeground_advantage  runs_scored_till_now  result
# 125                        1                     5       1
# 131                        1                    11       1
# 137                        1                    11       1
# 143                        1                    22       1
# 150                        1                    24       1
# ...                      ...                   ...     ...
# 196425                     1                    56       0
# 196431                     1                    59       0
# 196437                     1                    69       0
# 196444                     1                    77       0
# 196450                     1                    81       0
#
# [14958 rows x 14 columns]

# %%
temp_df = filter_temp_data(match)

# %%
temp_df.columns
# Out:
# Index(['ID', 'BattingTeam', 'BowlingTeam', 'Venue', 'runs_to_chase',
#        'balls_remaining', 'wickets left', 'total_run_x', 'crr', 'rrr',
#        'Tosswin', 'homeground_advantage', 'runs_scored_till_now', 'result'],
#       dtype='object')

# %%
temp_df['rrr'] = temp_df['rrr'].replace([np.inf, -np.inf], np.nan)

# Remove rows with NaN values
temp_df = temp_df.dropna(subset=['rrr'])

# %%
temp_df.describe()
# Out:
#                  ID  runs_to_chase  balls_remaining  wickets left  \
# count  1.467100e+04   14671.000000     14671.000000  14671.000000
# mean   8.404693e+05      92.276259        62.493082      7.554359
# std    3.475839e+05      48.158860        31.914034      2.079772
# min    3.359820e+05       1.000000         6.000000      0.000000
# 25%    5.012600e+05      54.000000        36.000000      6.000000
# 50%    8.297390e+05      91.000000        66.000000      8.000000
# 75%    1.178426e+06     128.000000        90.000000      9.000000
# max    1.312200e+06     232.000000       114.000000     10.000000
#
#         total_run_x           crr           rrr       Tosswin  \
# count  14671.000000  14671.000000  14671.000000  14671.000000
# mean     165.284984      7.433420      9.870707      0.487424
# std       28.672044      1.988035      6.076654      0.499859
# min       67.000000      0.000000      0.083333      0.000000
# 25%      147.000000      6.307692      7.166667      0.000000
# 50%      165.000000      7.473684      8.875000      0.000000
# 75%      185.000000      8.611111     10.947368      1.000000
# max      246.000000     21.000000    122.000000      1.000000
#
#        homeground_advantage  runs_scored_till_now        result
# count          14671.000000          14671.000000  14671.000000
# mean               0.207280             73.008725      0.524777
# std                0.405371             44.630007      0.499403
# min                0.000000              0.000000      0.000000
# 25%                0.000000             36.000000      0.000000
# 50%                0.000000             70.000000      1.000000
# 75%                0.000000            107.000000      1.000000
# max                1.000000            222.000000      1.000000

# %%
def predict_results(temp_df, pipe):
    result = pipe.predict_proba(temp_df)
    temp_df['lose'] = np.round(result.T[0] * 100, 1)
    temp_df['win'] = np.round(result.T[1] * 100, 1)
    return temp_df

# %%
predict_results(temp_df,pipe)
# Out:
#              ID                  BattingTeam                  BowlingTeam  \
# 125     1312200               Gujarat Titans             Rajasthan Royals
# 131     1312200               Gujarat Titans             Rajasthan Royals
# 137     1312200               Gujarat Titans             Rajasthan Royals
# 143     1312200               Gujarat Titans             Rajasthan Royals
# 150     1312200               Gujarat Titans             Rajasthan Royals
# ...         ...                          ...                          ...
# 196425   335982  Royal Challengers Bangalore  Royal Challengers Bangalore
# 196431   335982  Royal Challengers Bangalore  Royal Challengers Bangalore
# 196437   335982  Royal Challengers Bangalore  Royal Challengers Bangalore
# 196444   335982  Royal Challengers Bangalore  Royal Challengers Bangalore
# 196450   335982  Royal Challengers Bangalore  Royal Challengers Bangalore
#
#                                    Venue  runs_to_chase  balls_remaining  \
# 125     Narendra Modi Stadium, Ahmedabad            125              114
# 131     Narendra Modi Stadium, Ahmedabad            119              108
# 137     Narendra Modi Stadium, Ahmedabad            119              102
# 143     Narendra Modi Stadium, Ahmedabad            108               96
# 150     Narendra Modi Stadium, Ahmedabad            106               90
# ...                                  ...            ...              ...
# 196425             M Chinnaswamy Stadium            166               54
# 196431             M Chinnaswamy Stadium            163               48
# 196437             M Chinnaswamy Stadium            153               42
# 196444             M Chinnaswamy Stadium            145               36
# 196450             M Chinnaswamy Stadium            141               30
#
#         wickets left  total_run_x       crr        rrr  Tosswin  \
# 125               10          130  5.000000   6.578947        0
# 131                9          130  5.500000   6.611111        0
# 137                9          130  3.666667   7.000000        0
# 143                9          130  5.500000   6.750000        0
# 150                8          130  4.800000   7.066667        0
# ...              ...          ...       ...        ...      ...
# 196425             3          222  5.090909  18.444444        1
# 196431             2          222  4.916667  20.375000        1
# 196437             2          222  5.307692  21.857143        1
# 196444             1          222  5.500000  24.166667        1
# 196450             1          222  5.400000  28.200000        1
#
#         homeground_advantage  runs_scored_till_now  result  lose   win
# 125                        1                     5       1   9.5  90.5
# 131                        1                    11       1  10.6  89.4
# 137                        1                    11       1  16.4  83.6
# 143                        1                    22       1  13.3  86.7
# 150                        1                    24       1  18.7  81.3
# ...                      ...                   ...     ...   ...   ...
# 196425                     1                    56       0  99.6   0.4
# 196431                     1                    59       0  99.7   0.3
# 196437                     1                    69       0  99.7   0.3
# 196444                     1                    77       0  99.8   0.2
# 196450                     1                    81       0  99.8   0.2
#
# [14671 rows x 16 columns]

# %%
temp_df.columns
# Out:
# Index(['ID', 'BattingTeam', 'BowlingTeam', 'Venue', 'runs_to_chase',
#        'balls_remaining', 'wickets left', 'total_run_x', 'crr', 'rrr',
#        'Tosswin', 'homeground_advantage', 'runs_scored_till_now', 'result',
#        'lose', 'win'],
#       dtype='object')

# %%
def calculate_metrics(temp_df):
    temp_df['ID'] = temp_df['ID']
    temp_df['runs_to_chase'] = temp_df['runs_to_chase']
    temp_df['runs_scored_till_now'] =temp_df['runs_scored_till_now']
    temp_df['result'] = temp_df['result']
    temp_df['BattingTeam'] =temp_df['BattingTeam']
    temp_df['end_of_over'] = range(1, temp_df.shape[0] + 1)
    target = temp_df['total_run_x'].values[0]
    runs = list(temp_df['runs_to_chase'].values)
    new_runs = runs[:]
    runs.insert(0, target)
    temp_df['runs_after_over'] = np.array(runs)[:-1] - np.array(new_runs)
    wickets = list(temp_df['wickets left'].values)
    new_wickets = wickets[:]
    new_wickets.insert(0, 10)
    wickets.append(0)
    w = np.array(wickets)
    nw = np.array(new_wickets)
    temp_df['wickets_in_over'] = (nw - w)[:temp_df.shape[0]]
    return temp_df, target

# %%
calculate_metrics(temp_df)
# Out:
# (             ID                  BattingTeam                  BowlingTeam  \
#  125     1312200               Gujarat Titans             Rajasthan Royals
#  131     1312200               Gujarat Titans             Rajasthan Royals
#  137     1312200               Gujarat Titans             Rajasthan Royals
#  143     1312200               Gujarat Titans             Rajasthan Royals
#  150     1312200               Gujarat Titans             Rajasthan Royals
#  ...         ...                          ...                          ...
#  196425   335982  Royal Challengers Bangalore  Royal Challengers Bangalore
#  196431   335982  Royal Challengers Bangalore  Royal Challengers Bangalore
#  196437   335982  Royal Challengers Bangalore  Royal Challengers Bangalore
#  196444   335982  Royal Challengers Bangalore  Royal Challengers Bangalore
#  196450   335982  Royal Challengers Bangalore  Royal Challengers Bangalore
#
#                                     Venue  runs_to_chase  balls_remaining  \
#  125     Narendra Modi Stadium, Ahmedabad            125              114
#  131     Narendra Modi Stadium, Ahmedabad            119              108
#  137     Narendra Modi Stadium, Ahmedabad            119              102
#  143     Narendra Modi Stadium, Ahmedabad            108               96
#  150     Narendra Modi Stadium, Ahmedabad            106               90
#  ...                                  ...            ...              ...
#  196425             M Chinnaswamy Stadium            166               54
#  196431             M Chinnaswamy Stadium            163               48
#  196437             M Chinnaswamy Stadium            153               42
#  196444             M Chinnaswamy Stadium            145               36
#  196450             M Chinnaswamy Stadium            141               30
#
#          wickets left  total_run_x       crr        rrr  Tosswin  \
#  125               10          130  5.000000   6.578947        0
#  131                9          130  5.500000   6.611111        0
#  137                9          130  3.666667   7.000000        0
#  143                9          130  5.500000   6.750000        0
#  150                8          130  4.800000   7.066667        0
#  ...              ...          ...       ...        ...      ...
#  196425             3          222  5.090909  18.444444        1
#  196431             2          222  4.916667  20.375000        1
#  196437             2          222  5.307692  21.857143        1
#  196444             1          222  5.500000  24.166667        1
#  196450             1          222  5.400000  28.200000        1
#
#          homeground_advantage  runs_scored_till_now  result  lose   win  \
#  125                        1                     5       1   9.5  90.5
#  131                        1                    11       1  10.6  89.4
#  137                        1                    11       1  16.4  83.6
#  143                        1                    22       1  13.3  86.7
#  150                        1                    24       1  18.7  81.3
#  ...                      ...                   ...     ...   ...   ...
#  196425                     1                    56       0  99.6   0.4
#  196431                     1                    59       0  99.7   0.3
#  196437                     1                    69       0  99.7   0.3
#  196444                     1                    77       0  99.8   0.2
#  196450                     1                    81       0  99.8   0.2
#
#          end_of_over  runs_after_over  wickets_in_over
#  125               1                5                0
#  131               2                6                1
#  137               3                0                0
#  143               4               11                0
#  150               5                2                1
#  ...             ...              ...              ...
#  196425        14667                6                0
#  196431        14668                3                1
#  196437        14669               10                0
#  196444        14670                8                1
#  196450        14671                4                0
#
#  [14671 rows x 19 columns],
#  130)

# %%
temp_df.columns
# Out:
# Index(['ID', 'BattingTeam', 'BowlingTeam', 'Venue', 'runs_to_chase',
#        'balls_remaining', 'wickets left', 'total_run_x', 'crr', 'rrr',
#        'Tosswin', 'homeground_advantage', 'runs_scored_till_now', 'result',
#        'lose', 'win', 'end_of_over', 'runs_after_over', 'wickets_in_over'],
#       dtype='object')

# %%
temp_df
# Out:
#              ID                  BattingTeam                  BowlingTeam  \
# 125     1312200               Gujarat Titans             Rajasthan Royals
# 131     1312200               Gujarat Titans             Rajasthan Royals
# 137     1312200               Gujarat Titans             Rajasthan Royals
# 143     1312200               Gujarat Titans             Rajasthan Royals
# 150     1312200               Gujarat Titans             Rajasthan Royals
# ...         ...                          ...                          ...
# 196425   335982  Royal Challengers Bangalore  Royal Challengers Bangalore
# 196431   335982  Royal Challengers Bangalore  Royal Challengers Bangalore
# 196437   335982  Royal Challengers Bangalore  Royal Challengers Bangalore
# 196444   335982  Royal Challengers Bangalore  Royal Challengers Bangalore
# 196450   335982  Royal Challengers Bangalore  Royal Challengers Bangalore
#
#                                    Venue  runs_to_chase  balls_remaining  \
# 125     Narendra Modi Stadium, Ahmedabad            125              114
# 131     Narendra Modi Stadium, Ahmedabad            119              108
# 137     Narendra Modi Stadium, Ahmedabad            119              102
# 143     Narendra Modi Stadium, Ahmedabad            108               96
# 150     Narendra Modi Stadium, Ahmedabad            106               90
# ...                                  ...            ...              ...
# 196425             M Chinnaswamy Stadium            166               54
# 196431             M Chinnaswamy Stadium            163               48
# 196437             M Chinnaswamy Stadium            153               42
# 196444             M Chinnaswamy Stadium            145               36
# 196450             M Chinnaswamy Stadium            141               30
#
#         wickets left  total_run_x       crr        rrr  Tosswin  \
# 125               10          130  5.000000   6.578947        0
# 131                9          130  5.500000   6.611111        0
# 137                9          130  3.666667   7.000000        0
# 143                9          130  5.500000   6.750000        0
# 150                8          130  4.800000   7.066667        0
# ...              ...          ...       ...        ...      ...
# 196425             3          222  5.090909  18.444444        1
# 196431             2          222  4.916667  20.375000        1
# 196437             2          222  5.307692  21.857143        1
# 196444             1          222  5.500000  24.166667        1
# 196450             1          222  5.400000  28.200000        1
#
#         homeground_advantage  runs_scored_till_now  result  lose   win  \
# 125                        1                     5       1   9.5  90.5
# 131                        1                    11       1  10.6  89.4
# 137                        1                    11       1  16.4  83.6
# 143                        1                    22       1  13.3  86.7
# 150                        1                    24       1  18.7  81.3
# ...                      ...                   ...     ...   ...   ...
# 196425                     1                    56       0  99.6   0.4
# 196431                     1                    59       0  99.7   0.3
# 196437                     1                    69       0  99.7   0.3
# 196444                     1                    77       0  99.8   0.2
# 196450                     1                    81       0  99.8   0.2
#
#         end_of_over  runs_after_over  wickets_in_over
# 125               1                5                0
# 131               2                6                1
# 137               3                0                0
# 143               4               11                0
# 150               5                2                1
# ...             ...              ...              ...
# 196425        14667                6                0
# 196431        14668                3                1
# 196437        14669               10                0
# 196444        14670                8                1
# 196450        14671                4                0
#
# [14671 rows x 19 columns]

# %%
def get_target_and_progression(x_df, pipe):
    y, target = calculate_metrics(temp_df)
    return target, y[['ID', 'runs_scored_till_now', 'wickets left', 'lose', 'win']]

# %%
get_target_and_progression(merged,pipe)
# Out:
# (130,
#               ID  runs_scored_till_now  wickets left  lose   win
#  125     1312200                     5            10   9.5  90.5
#  131     1312200                    11             9  10.6  89.4
#  137     1312200                    11             9  16.4  83.6
#  143     1312200                    22             9  13.3  86.7
#  150     1312200                    24             8  18.7  81.3
#  ...         ...                   ...           ...   ...   ...
#  196425   335982                    56             3  99.6   0.4
#  196431   335982                    59             2  99.7   0.3
#  196437   335982                    69             2  99.7   0.3
#  196444   335982                    77             1  99.8   0.2
#  196450   335982                    81             1  99.8   0.2
#
#  [14671 rows x 5 columns])

# %%
def match_progression(x_df, pipe):
    target, progression = get_target_and_progression(x_df, pipe)
    print("Target -", target)
    return progression

# %%
match_progress=match_progression(temp_df,pipe)
# Out:
# Target - 130

# %%
#for a specific match
match_progress[match_progress['ID'] == 335982]
# Out:
#             ID  runs_scored_till_now  wickets left  lose  win
# 196358  335982                     4            10  96.8  3.2
# 196365  335982                     9             9  97.4  2.6
# 196371  335982                    11             8  98.3  1.7
# 196378  335982                    16             8  98.6  1.4
# 196384  335982                    24             7  98.6  1.4
# 196390  335982                    26             6  99.1  0.9
# 196396  335982                    29             6  99.3  0.7
# 196404  335982                    38             5  99.3  0.7
# 196410  335982                    41             4  99.5  0.5
# 196418  335982                    50             3  99.5  0.5
# 196425  335982                    56             3  99.6  0.4
# 196431  335982                    59             2  99.7  0.3
# 196437  335982                    69             2  99.7  0.3
# 196444  335982                    77             1  99.8  0.2
# 196450  335982                    81             1  99.8  0.2

# %%
match_progress=match_progression(temp_df,pipe)
# Out:
# Target - 130

# %%
#for a specific match
match_progress[match_progress['ID'] == 1312200]
# Out:
#           ID  runs_scored_till_now  wickets left  lose   win
# 125  1312200                     5            10   9.5  90.5
# 131  1312200                    11             9  10.6  89.4
# 137  1312200                    11             9  16.4  83.6
# 143  1312200                    22             9  13.3  86.7
# 150  1312200                    24             8  18.7  81.3
# 158  1312200                    31             8  19.2  80.8
# 164  1312200                    35             8  23.1  76.9
# 170  1312200                    38             8  28.9  71.1
# 176  1312200                    48             8  25.6  74.4
# 182  1312200                    54             8  27.7  72.3
# 188  1312200                    62             8  27.0  73.0
# 194  1312200                    77             8  18.1  81.9
# 200  1312200                    84             8  18.6  81.4
# 206  1312200                    89             7  21.9  78.1
# 212  1312200                    97             7  21.2  78.8
# 218  1312200                   109             7  15.9  84.1
# 224  1312200                   120             7  12.0  88.0
# 231  1312200                   127             7  11.2  88.8

# %%
temp_df.columns
# Out:
# Index(['ID', 'BattingTeam', 'BowlingTeam', 'Venue', 'runs_to_chase',
#        'balls_remaining', 'wickets left', 'total_run_x', 'crr', 'rrr',
#        'Tosswin', 'homeground_advantage', 'runs_scored_till_now', 'result',
#        'lose', 'win', 'end_of_over', 'runs_after_over', 'wickets_in_over'],
#       dtype='object')

# %%
merged.columns
# Out:
# Index(['ID', 'Venue', 'WinningTeam', 'total_run_x', 'BowlingTeam', 'Team2',
#        'TossWinner', 'innings', 'overs', 'ballnumber', 'batter', 'bowler',
#        'non-striker', 'extra_type', 'batsman_run', 'extras_run', 'total_run_y',
#        'non_boundary', 'isWicketDelivery', 'player_out', 'kind',
#        'fielders_involved', 'BattingTeam', 'runs_scored_till_now',
#        'runs_to_chase', 'balls_remaining', 'wickets taken', 'wickets left',
#        'Tosswin', 'homeground_advantage', 'crr', 'rrr', 'result'],
#       dtype='object')

# %%
match_progress.columns
# Out:
# Index(['ID', 'runs_scored_till_now', 'wickets left', 'lose', 'win'], dtype='object')

# %%
columns_to_keep=['runs_scored_till_now','wickets left','Tosswin','homeground_advantage']
x=X_train[columns_to_keep]

y=Y_train

# %%
model=pd.merge(x,y,left_index=True, right_index=True)

# %%
x.corr()
# Out:
#                       runs_scored_till_now  wickets left   Tosswin  \
# runs_scored_till_now              1.000000     -0.625988  0.018339
# wickets left                     -0.625988      1.000000 -0.009499
# Tosswin                           0.018339     -0.009499  1.000000
# homeground_advantage             -0.007834      0.032407  0.085719
#
#                       homeground_advantage
# runs_scored_till_now             -0.007834
# wickets left                      0.032407
# Tosswin                           0.085719
# homeground_advantage              1.000000

# %%
sns.heatmap(x.corr(),annot=True)
plt.show()

# %% [markdown]
# Since correlation coefficient between wickets left and runs scored till now seems to be a bit high we want to check for multicolinearity

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif_data = pd.DataFrame()
vif_data["Feature"] = x.columns
vif_data["VIF"] = [variance_inflation_factor(x.values, i) for i in range(x.shape[1])]

# %%
vif_data
# Out:
#                 Feature       VIF
# 0  runs_scored_till_now  2.200607
# 1          wickets left  2.676999
# 2               Tosswin  1.926759
# 3  homeground_advantage  1.269384

# %% [markdown]
# Since VIF<10 for all Features, we conclude that there is no significant multicolinearity and we proceed with calculating the coefficients

# %%
from sklearn.linear_model import LogisticRegression
import numpy as np

# %% [markdown]
# coefficients

# %%
logreg = LogisticRegression()

# %%
logreg.fit(x, y)
# Out:
# LogisticRegression()

# %%
coefficients = logreg.coef_[0]
intercept = logreg.intercept_
column_names = x.columns

# %%
print("Coefficients:", coefficients)
print("Intercept:", intercept)
# Out:
# Coefficients: [0.01961472 0.66781157 0.1913438  0.46161487]
# Intercept: [-6.59735386]

# %%
x.columns
# Out:
# Index(['runs_scored_till_now', 'wickets left', 'Tosswin',
#        'homeground_advantage'],
#       dtype='object')

# %%
for feature, coef in zip(column_names, coefficients):
    print(f'{feature}: {coef}')
# Out:
# runs_scored_till_now: 0.019614718798471854
# wickets left: 0.6678115675516477
# Tosswin: 0.1913437970706685
# homeground_advantage: 0.46161486568290633

# %%
Coefficients_df = pd.DataFrame()
Coefficients_df['Feature'] = x.columns
Coefficients_df['Coefficients']= coefficients

# %%
Coefficients_df
# Out:
#                 Feature  Coefficients
# 0  runs_scored_till_now      0.019615
# 1          wickets left      0.667812
# 2               Tosswin      0.191344
# 3  homeground_advantage      0.461615

# %% [markdown]
# Logistic Regression

# %%
#Confusion Matrix
from sklearn.metrics import confusion_matrix

# %%
cm = confusion_matrix(y_true = Y_test, y_pred = Y_pred,labels = (1,0))

# %%
plt.figure(figsize=(3, 3))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", cbar=False)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()


plt.show()

# %%
tp, fn ,fp ,tn = confusion_matrix(y_true = Y_test, y_pred = Y_pred,labels = (1,0)).ravel()

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
precision_score(Y_test, Y_pred)
# Out:
# 0.7689149560117302

# %%
recall_score(Y_test, Y_pred)
# Out:
# 0.803965658217498

# %%
f1_score(Y_test, Y_pred)
# Out:
# 0.786049765164385

# %%
accuracy_score(Y_test, Y_pred)
# Out:
# 0.7722582703967663

# %% [markdown]
# Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
pipe1 = Pipeline(steps=[
    ("step1", trf),
    ("step2",RandomForestClassifier())
])

# %%
pipe1.fit(X_train,Y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('trf',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse=False),
#                                                   ['BattingTeam', 'BowlingTeam',
#                                                    'Venue'])])),
#                 ('step2', RandomForestClassifier())])

# %%
y1_pred  = pipe1.predict(X_test)

# %%
#Confusion Matrix
from sklearn.metrics import confusion_matrix
cm1 = confusion_matrix(y_true = Y_test, y_pred = y1_pred,labels = (1,0))
plt.figure(figsize=(3, 3))
sns.heatmap(cm, annot=True, fmt="d", cmap="Greens", cbar=False)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()


plt.show()

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
precision_score(Y_test, y1_pred)
# Out:
# 0.999795605518651

# %%
recall_score(Y_test, y1_pred)
# Out:
# 0.999897792313982

# %%
f1_score(Y_test, y1_pred)
# Out:
# 0.9998466963053809

# %%
accuracy_score(Y_test, y1_pred)
# Out:
# 0.9998404425061164

# %% [markdown]
# Random Forest

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
pipe2 = Pipeline(steps=[
    ("step1", trf),
    ("step2",RandomForestClassifier())
])

# %%
pipe2.fit(X_train,Y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('trf',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse=False),
#                                                   ['BattingTeam', 'BowlingTeam',
#                                                    'Venue'])])),
#                 ('step2', RandomForestClassifier())])

# %%
y2_pred  = pipe2.predict(X_test)

# %%
#Confusion Matrix
from sklearn.metrics import confusion_matrix
cm1 = confusion_matrix(y_true = Y_test, y_pred = y2_pred,labels = (1,0))
plt.figure(figsize=(3, 3))
sns.heatmap(cm, annot=True, fmt="d", cmap="Oranges", cbar=False)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()


plt.show()

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
precision_score(Y_test, y2_pred)
# Out:
# 0.9998978027593255

# %%
recall_score(Y_test, y2_pred)
# Out:
# 1.0

# %%
f1_score(Y_test,y2_pred)
# Out:
# 0.9999488987684603

# %%
accuracy_score(Y_test,y2_pred)
# Out:
# 0.9999468141687055
